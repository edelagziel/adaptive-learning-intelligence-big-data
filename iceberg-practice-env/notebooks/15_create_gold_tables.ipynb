# %%
spark.sql("""
CREATE TABLE IF NOT EXISTS demo.gold.dim_learner (
    user_key INT,
    user_id STRING,

    registration_date DATE,
    preferred_language STRING,
    background_level STRING,
    learning_goal STRING,
    main_domain STRING,

    profile_updated_at TIMESTAMP,
    is_active BOOLEAN
)
USING iceberg
""")
# Out:
# DataFrame[]

# %%
spark.sql("""
DESCRIBE TABLE demo.gold.dim_learner
""").show(100, truncate=False)
# Out:
# +------------------+---------+-------+
# |col_name          |data_type|comment|
# +------------------+---------+-------+
# |user_key          |int      |NULL   |
# |user_id           |string   |NULL   |
# |registration_date |date     |NULL   |
# |preferred_language|string   |NULL   |
# |background_level  |string   |NULL   |
# |learning_goal     |string   |NULL   |
# |main_domain       |string   |NULL   |
# |profile_updated_at|timestamp|NULL   |
# |is_active         |boolean  |NULL   |
# +------------------+---------+-------+

# %%
spark.sql("""
SELECT COUNT(*) AS row_count
FROM demo.gold.dim_learner
""").show()
# Out:
# +---------+
# |row_count|
# +---------+
# |        0|
# +---------+

# %%
spark.sql("""
CREATE TABLE IF NOT EXISTS demo.gold.dim_topic (
    topic_key INT,
    taxonomy_id STRING,
    topic_id STRING,

    topic_name STRING,
    normalized_topic_name STRING,

    domain STRING,
    parent_topic_key INT,

    taxonomy_level STRING,
    first_detected_at TIMESTAMP,
    validation_status STRING,
    is_active BOOLEAN
)
USING iceberg
""")
# Out:
# DataFrame[]

# %%
spark.sql("""
DESCRIBE TABLE demo.gold.dim_topic
""").show(100, truncate=False)
# Out:
# +---------------------+---------+-------+
# |col_name             |data_type|comment|
# +---------------------+---------+-------+
# |topic_key            |int      |NULL   |
# |taxonomy_id          |string   |NULL   |
# |topic_id             |string   |NULL   |
# |topic_name           |string   |NULL   |
# |normalized_topic_name|string   |NULL   |
# |domain               |string   |NULL   |
# |parent_topic_key     |int      |NULL   |
# |taxonomy_level       |string   |NULL   |
# |first_detected_at    |timestamp|NULL   |
# |validation_status    |string   |NULL   |
# |is_active            |boolean  |NULL   |
# +---------------------+---------+-------+

# %%
spark.sql("""
SELECT COUNT(*) AS row_count
FROM demo.gold.dim_topic
""").show()
# Out:
# +---------+
# |row_count|
# +---------+
# |        0|
# +---------+

# %%
spark.sql("""
CREATE TABLE IF NOT EXISTS demo.gold.dim_content_type (
    content_type_key INT,
    content_type_id STRING,
    content_type_name STRING,

    category STRING,
    academic_orientation STRING,

    requires_logic BOOLEAN,
    requires_numerical_reasoning BOOLEAN,
    requires_text_interpretation BOOLEAN,
    requires_visual_reasoning BOOLEAN,
    requires_memorization BOOLEAN,

    description STRING
)
USING iceberg
""")
# Out:
# DataFrame[]

# %%
spark.sql("""
DESCRIBE TABLE demo.gold.dim_content_type
""").show(100, truncate=False)
# Out:
# +----------------------------+---------+-------+
# |col_name                    |data_type|comment|
# +----------------------------+---------+-------+
# |content_type_key            |int      |NULL   |
# |content_type_id             |string   |NULL   |
# |content_type_name           |string   |NULL   |
# |category                    |string   |NULL   |
# |academic_orientation        |string   |NULL   |
# |requires_logic              |boolean  |NULL   |
# |requires_numerical_reasoning|boolean  |NULL   |
# |requires_text_interpretation|boolean  |NULL   |
# |requires_visual_reasoning   |boolean  |NULL   |
# |requires_memorization       |boolean  |NULL   |
# |description                 |string   |NULL   |
# +----------------------------+---------+-------+

# %%
spark.sql("""
SELECT COUNT(*) AS row_count
FROM demo.gold.dim_content_type
""").show()
# Out:
# +---------+
# |row_count|
# +---------+
# |        0|
# +---------+

# %%
spark.sql("""
CREATE TABLE IF NOT EXISTS demo.gold.dim_reference_source (
    reference_key INT,
    reference_id STRING,

    source_name STRING,
    source_type STRING,
    file_name STRING,

    reliability_level STRING,
    domain STRING,

    is_active BOOLEAN
)
USING iceberg
""")
# Out:
# DataFrame[]

# %%
spark.sql("""
DESCRIBE TABLE demo.gold.dim_reference_source
""").show(100, truncate=False)
# Out:
# +-----------------+---------+-------+
# |col_name         |data_type|comment|
# +-----------------+---------+-------+
# |reference_key    |int      |NULL   |
# |reference_id     |string   |NULL   |
# |source_name      |string   |NULL   |
# |source_type      |string   |NULL   |
# |file_name        |string   |NULL   |
# |reliability_level|string   |NULL   |
# |domain           |string   |NULL   |
# |is_active        |boolean  |NULL   |
# +-----------------+---------+-------+

# %%
spark.sql("""
SELECT COUNT(*) AS row_count
FROM demo.gold.dim_reference_source
""").show()
# Out:
# +---------+
# |row_count|
# +---------+
# |        0|
# +---------+

# %%
spark.sql("""
CREATE TABLE IF NOT EXISTS demo.gold.fact_learning_interaction (
    interaction_key STRING,
    event_id STRING,

    user_key INT,
    session_id STRING,
    topic_key INT,

    event_time TIMESTAMP,
    event_date DATE,
    event_hour INT,

    event_type STRING,
    source_system STRING,
    is_practice_event BOOLEAN,

    attempt_id STRING,
    question_id STRING,
    is_correct BOOLEAN,
    score FLOAT,
    hints_used INT,
    attempt_duration_seconds INT,
    attempt_number INT
)
USING iceberg
""")
# Out:
# DataFrame[]

# %%
spark.sql("""
DESCRIBE TABLE demo.gold.fact_learning_interaction
""").show(100, truncate=False)
# Out:
# +------------------------+---------+-------+
# |col_name                |data_type|comment|
# +------------------------+---------+-------+
# |interaction_key         |string   |NULL   |
# |event_id                |string   |NULL   |
# |user_key                |int      |NULL   |
# |session_id              |string   |NULL   |
# |topic_key               |int      |NULL   |
# |event_time              |timestamp|NULL   |
# |event_date              |date     |NULL   |
# |event_hour              |int      |NULL   |
# |event_type              |string   |NULL   |
# |source_system           |string   |NULL   |
# |is_practice_event       |boolean  |NULL   |
# |attempt_id              |string   |NULL   |
# |question_id             |string   |NULL   |
# |is_correct              |boolean  |NULL   |
# |score                   |float    |NULL   |
# |hints_used              |int      |NULL   |
# |attempt_duration_seconds|int      |NULL   |
# |attempt_number          |int      |NULL   |
# +------------------------+---------+-------+

# %%
spark.sql("""
SELECT COUNT(*) AS row_count
FROM demo.gold.fact_learning_interaction
""").show()
# Out:
# +---------+
# |row_count|
# +---------+
# |        0|
# +---------+

# %%
spark.sql("""
CREATE TABLE IF NOT EXISTS demo.gold.fact_learning_session (
    session_id STRING,
    user_key INT,

    session_start_time TIMESTAMP,
    session_end_time TIMESTAMP,
    session_duration_minutes INT,

    main_source_system STRING,

    total_events INT,
    total_attempts INT,
    total_hints_used INT,
    average_practice_score FLOAT,

    session_status STRING
)
USING iceberg
""")
# Out:
# DataFrame[]

# %%
spark.sql("""
DESCRIBE TABLE demo.gold.fact_learning_session
""").show(100, truncate=False)
# Out:
# +------------------------+---------+-------+
# |col_name                |data_type|comment|
# +------------------------+---------+-------+
# |session_id              |string   |NULL   |
# |user_key                |int      |NULL   |
# |session_start_time      |timestamp|NULL   |
# |session_end_time        |timestamp|NULL   |
# |session_duration_minutes|int      |NULL   |
# |main_source_system      |string   |NULL   |
# |total_events            |int      |NULL   |
# |total_attempts          |int      |NULL   |
# |total_hints_used        |int      |NULL   |
# |average_practice_score  |float    |NULL   |
# |session_status          |string   |NULL   |
# +------------------------+---------+-------+

# %%
spark.sql("""
SELECT COUNT(*) AS row_count
FROM demo.gold.fact_learning_session
""").show()
# Out:
# +---------+
# |row_count|
# +---------+
# |        0|
# +---------+

# %%
spark.sql("""
CREATE TABLE IF NOT EXISTS demo.gold.fact_learning_feedback (
    feedback_key STRING,

    user_key INT,
    session_id STRING,
    topic_key INT,
    practice_id STRING,

    feedback_stage STRING,
    feedback_time TIMESTAMP,
    ingestion_time TIMESTAMP,
    delay_minutes INT,

    confidence_score INT,
    perceived_understanding_score INT,
    perceived_difficulty_score INT,
    motivation_score INT,
    stress_score INT,

    still_confused BOOLEAN
)
USING iceberg
""")
# Out:
# DataFrame[]

# %%
spark.sql("""
DESCRIBE TABLE demo.gold.fact_learning_feedback
""").show(100, truncate=False)
# Out:
# +-----------------------------+---------+-------+
# |col_name                     |data_type|comment|
# +-----------------------------+---------+-------+
# |feedback_key                 |string   |NULL   |
# |user_key                     |int      |NULL   |
# |session_id                   |string   |NULL   |
# |topic_key                    |int      |NULL   |
# |practice_id                  |string   |NULL   |
# |feedback_stage               |string   |NULL   |
# |feedback_time                |timestamp|NULL   |
# |ingestion_time               |timestamp|NULL   |
# |delay_minutes                |int      |NULL   |
# |confidence_score             |int      |NULL   |
# |perceived_understanding_score|int      |NULL   |
# |perceived_difficulty_score   |int      |NULL   |
# |motivation_score             |int      |NULL   |
# |stress_score                 |int      |NULL   |
# |still_confused               |boolean  |NULL   |
# +-----------------------------+---------+-------+

# %%
spark.sql("""
SELECT COUNT(*) AS row_count
FROM demo.gold.fact_learning_feedback
""").show()
# Out:
# +---------+
# |row_count|
# +---------+
# |        0|
# +---------+

# %%
spark.sql("""
CREATE TABLE IF NOT EXISTS demo.gold.fact_ai_insight_validation (
    validation_key STRING,
    validation_id STRING,
    insight_id STRING,
    event_id STRING,

    user_key INT,
    session_id STRING,
    topic_key INT,
    reference_key INT,

    dynamic_concept_name STRING,

    extracted_at TIMESTAMP,
    validation_time TIMESTAMP,

    extraction_confidence FLOAT,
    semantic_match_score FLOAT,
    reliability_score FLOAT,

    contradiction_flag BOOLEAN,
    validation_status STRING,

    match_rank INT
)
USING iceberg
""")
# Out:
# DataFrame[]

# %%
spark.sql("""
DESCRIBE TABLE demo.gold.fact_ai_insight_validation
""").show(100, truncate=False)
# Out:
# +---------------------+---------+-------+
# |col_name             |data_type|comment|
# +---------------------+---------+-------+
# |validation_key       |string   |NULL   |
# |validation_id        |string   |NULL   |
# |insight_id           |string   |NULL   |
# |event_id             |string   |NULL   |
# |user_key             |int      |NULL   |
# |session_id           |string   |NULL   |
# |topic_key            |int      |NULL   |
# |reference_key        |int      |NULL   |
# |dynamic_concept_name |string   |NULL   |
# |extracted_at         |timestamp|NULL   |
# |validation_time      |timestamp|NULL   |
# |extraction_confidence|float    |NULL   |
# |semantic_match_score |float    |NULL   |
# |reliability_score    |float    |NULL   |
# |contradiction_flag   |boolean  |NULL   |
# |validation_status    |string   |NULL   |
# |match_rank           |int      |NULL   |
# +---------------------+---------+-------+

# %%
spark.sql("""
SELECT COUNT(*) AS row_count
FROM demo.gold.fact_ai_insight_validation
""").show()
# Out:
# +---------+
# |row_count|
# +---------+
# |        0|
# +---------+

# %%
spark.sql("""
CREATE TABLE IF NOT EXISTS demo.gold.fact_learner_concept_state (
    concept_state_key STRING,

    user_key INT,
    topic_key INT,

    state_version INT,

    mastery_score FLOAT,
    difficulty_score FLOAT,
    confidence_score FLOAT,

    repeated_mistake_count INT,
    last_practice_score FLOAT,
    struggle_risk_score FLOAT,

    evidence_count INT,
    last_evidence_time TIMESTAMP,

    state_calculation_version STRING,

    valid_from TIMESTAMP,
    valid_to TIMESTAMP,
    is_current BOOLEAN
)
USING iceberg
""")
# Out:
# DataFrame[]

# %%
spark.sql("""
DESCRIBE TABLE demo.gold.fact_learner_concept_state
""").show(100, truncate=False)
# Out:
# +-------------------------+---------+-------+
# |col_name                 |data_type|comment|
# +-------------------------+---------+-------+
# |concept_state_key        |string   |NULL   |
# |user_key                 |int      |NULL   |
# |topic_key                |int      |NULL   |
# |state_version            |int      |NULL   |
# |mastery_score            |float    |NULL   |
# |difficulty_score         |float    |NULL   |
# |confidence_score         |float    |NULL   |
# |repeated_mistake_count   |int      |NULL   |
# |last_practice_score      |float    |NULL   |
# |struggle_risk_score      |float    |NULL   |
# |evidence_count           |int      |NULL   |
# |last_evidence_time       |timestamp|NULL   |
# |state_calculation_version|string   |NULL   |
# |valid_from               |timestamp|NULL   |
# |valid_to                 |timestamp|NULL   |
# |is_current               |boolean  |NULL   |
# +-------------------------+---------+-------+

# %%
spark.sql("""
SELECT COUNT(*) AS row_count
FROM demo.gold.fact_learner_concept_state
""").show()
# Out:
# +---------+
# |row_count|
# +---------+
# |        0|
# +---------+

# %%
spark.sql("""
CREATE TABLE IF NOT EXISTS demo.gold.agg_learner_overview_daily (
    user_key INT,
    date DATE,

    total_sessions INT,
    total_learning_events INT,
    topics_practiced INT,

    weak_topics_count INT,
    repeated_mistakes_count INT,
    avg_mastery_score FLOAT,
    at_risk_topics_count INT,

    avg_reliability_score FLOAT,

    avg_motivation_score FLOAT,
    avg_stress_score FLOAT,
    avg_self_reported_understanding FLOAT
)
USING iceberg
""")
# Out:
# DataFrame[]

# %%
spark.sql("""
DESCRIBE TABLE demo.gold.agg_learner_overview_daily
""").show(100, truncate=False)
# Out:
# +-------------------------------+---------+-------+
# |col_name                       |data_type|comment|
# +-------------------------------+---------+-------+
# |user_key                       |int      |NULL   |
# |date                           |date     |NULL   |
# |total_sessions                 |int      |NULL   |
# |total_learning_events          |int      |NULL   |
# |topics_practiced               |int      |NULL   |
# |weak_topics_count              |int      |NULL   |
# |repeated_mistakes_count        |int      |NULL   |
# |avg_mastery_score              |float    |NULL   |
# |at_risk_topics_count           |int      |NULL   |
# |avg_reliability_score          |float    |NULL   |
# |avg_motivation_score           |float    |NULL   |
# |avg_stress_score               |float    |NULL   |
# |avg_self_reported_understanding|float    |NULL   |
# +-------------------------------+---------+-------+

# %%
spark.sql("""
SELECT COUNT(*) AS row_count
FROM demo.gold.agg_learner_overview_daily
""").show()
# Out:
# +---------+
# |row_count|
# +---------+
# |        0|
# +---------+

# %%
spark.sql("""
CREATE TABLE IF NOT EXISTS demo.gold.agg_concept_weakness_daily (
    user_key INT,
    topic_key INT,
    date DATE,

    failure_rate FLOAT,
    avg_score FLOAT,
    avg_hints_used FLOAT,

    repeated_mistake_count INT,
    avg_confidence_score FLOAT,
    difficulty_score FLOAT,

    weakness_rank INT
)
USING iceberg
""")
# Out:
# DataFrame[]

# %%
spark.sql("""
DESCRIBE TABLE demo.gold.agg_concept_weakness_daily
""").show(100, truncate=False)
# Out:
# +----------------------+---------+-------+
# |col_name              |data_type|comment|
# +----------------------+---------+-------+
# |user_key              |int      |NULL   |
# |topic_key             |int      |NULL   |
# |date                  |date     |NULL   |
# |failure_rate          |float    |NULL   |
# |avg_score             |float    |NULL   |
# |avg_hints_used        |float    |NULL   |
# |repeated_mistake_count|int      |NULL   |
# |avg_confidence_score  |float    |NULL   |
# |difficulty_score      |float    |NULL   |
# |weakness_rank         |int      |NULL   |
# +----------------------+---------+-------+

# %%
spark.sql("""
SELECT COUNT(*) AS row_count
FROM demo.gold.agg_concept_weakness_daily
""").show()
# Out:
# +---------+
# |row_count|
# +---------+
# |        0|
# +---------+

# %%
spark.sql("""
CREATE TABLE IF NOT EXISTS demo.gold.agg_learning_progress_daily (
    user_key INT,
    date DATE,

    avg_mastery_score FLOAT,
    avg_practice_score FLOAT,

    total_attempts INT,
    successful_attempts INT,

    hint_usage_rate FLOAT,
    still_confused_rate FLOAT
)
USING iceberg
""")
# Out:
# DataFrame[]

# %%
spark.sql("""
DESCRIBE TABLE demo.gold.agg_learning_progress_daily
""").show(100, truncate=False)
# Out:
# +-------------------+---------+-------+
# |col_name           |data_type|comment|
# +-------------------+---------+-------+
# |user_key           |int      |NULL   |
# |date               |date     |NULL   |
# |avg_mastery_score  |float    |NULL   |
# |avg_practice_score |float    |NULL   |
# |total_attempts     |int      |NULL   |
# |successful_attempts|int      |NULL   |
# |hint_usage_rate    |float    |NULL   |
# |still_confused_rate|float    |NULL   |
# +-------------------+---------+-------+

# %%
spark.sql("""
SELECT COUNT(*) AS row_count
FROM demo.gold.agg_learning_progress_daily
""").show()
# Out:
# +---------+
# |row_count|
# +---------+
# |        0|
# +---------+

# %%
spark.sql("""
CREATE TABLE IF NOT EXISTS demo.gold.agg_illusion_of_learning (
    user_key INT,
    topic_key INT,
    session_id STRING,

    confidence_before INT,
    practice_score FLOAT,
    confidence_after INT,

    confidence_drop INT,
    illusion_gap_score FLOAT,
    illusion_flag BOOLEAN
)
USING iceberg
""")
# Out:
# DataFrame[]

# %%
spark.sql("""
DESCRIBE TABLE demo.gold.agg_illusion_of_learning
""").show(100, truncate=False)
# Out:
# +------------------+---------+-------+
# |col_name          |data_type|comment|
# +------------------+---------+-------+
# |user_key          |int      |NULL   |
# |topic_key         |int      |NULL   |
# |session_id        |string   |NULL   |
# |confidence_before |int      |NULL   |
# |practice_score    |float    |NULL   |
# |confidence_after  |int      |NULL   |
# |confidence_drop   |int      |NULL   |
# |illusion_gap_score|float    |NULL   |
# |illusion_flag     |boolean  |NULL   |
# +------------------+---------+-------+

# %%
spark.sql("""
SELECT COUNT(*) AS row_count
FROM demo.gold.agg_illusion_of_learning
""").show()
# Out:
# +---------+
# |row_count|
# +---------+
# |        0|
# +---------+

# %%
spark.sql("""
CREATE TABLE IF NOT EXISTS demo.gold.ml_learning_difficulty_features (
    user_key INT,
    topic_key INT,
    session_id STRING,

    avg_score_last_7_days FLOAT,
    failure_rate_last_7_days FLOAT,
    hints_used_last_7_days INT,
    avg_attempt_duration FLOAT,

    confidence_before_avg FLOAT,
    confidence_after_avg FLOAT,
    still_confused_rate FLOAT,
    illusion_gap_score FLOAT,

    repeated_mistake_count INT,

    extraction_confidence_avg FLOAT,
    reliability_score_avg FLOAT,

    overall_motivation_avg FLOAT,
    overall_stress_avg FLOAT,

    topic_self_reported_understanding_avg FLOAT,
    topic_confidence_avg FLOAT
)
USING iceberg
""")
# Out:
# DataFrame[]

# %%
spark.sql("""
DESCRIBE TABLE demo.gold.ml_learning_difficulty_features
""").show(100, truncate=False)
# Out:
# +-------------------------------------+---------+-------+
# |col_name                             |data_type|comment|
# +-------------------------------------+---------+-------+
# |user_key                             |int      |NULL   |
# |topic_key                            |int      |NULL   |
# |session_id                           |string   |NULL   |
# |avg_score_last_7_days                |float    |NULL   |
# |failure_rate_last_7_days             |float    |NULL   |
# |hints_used_last_7_days               |int      |NULL   |
# |avg_attempt_duration                 |float    |NULL   |
# |confidence_before_avg                |float    |NULL   |
# |confidence_after_avg                 |float    |NULL   |
# |still_confused_rate                  |float    |NULL   |
# |illusion_gap_score                   |float    |NULL   |
# |repeated_mistake_count               |int      |NULL   |
# |extraction_confidence_avg            |float    |NULL   |
# |reliability_score_avg                |float    |NULL   |
# |overall_motivation_avg               |float    |NULL   |
# |overall_stress_avg                   |float    |NULL   |
# |topic_self_reported_understanding_avg|float    |NULL   |
# |topic_confidence_avg                 |float    |NULL   |
# +-------------------------------------+---------+-------+

# %%
spark.sql("""
SELECT COUNT(*) AS row_count
FROM demo.gold.ml_learning_difficulty_features
""").show()
# Out:
# +---------+
# |row_count|
# +---------+
# |        0|
# +---------+
