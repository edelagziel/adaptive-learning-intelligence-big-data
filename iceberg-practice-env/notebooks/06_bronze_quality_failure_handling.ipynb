# %%
spark.sql("""
CREATE NAMESPACE IF NOT EXISTS demo.quality
""")
# Out:
# DataFrame[]

# %%
spark.sql("""
SHOW NAMESPACES IN demo
""").show()
# Out:
# +---------+
# |namespace|
# +---------+
# |   bronze|
# |     gold|
# |  quality|
# |   silver|
# +---------+

# %%
spark.sql("""
CREATE TABLE IF NOT EXISTS demo.quality.bronze_quality_results (
    check_id STRING,
    check_time TIMESTAMP,
    source_table STRING,
    rule_name STRING,
    severity STRING,
    total_rows BIGINT,
    failed_rows BIGINT,
    status STRING,
    action_taken STRING,
    details STRING
)
USING iceberg
""")
# Out:
# DataFrame[]

# %%
spark.sql("""
SHOW TABLES IN demo.quality
""").show()
# Out:
# +---------+--------------------+-----------+
# |namespace|           tableName|isTemporary|
# +---------+--------------------+-----------+
# |  quality|bronze_quality_re...|      false|
# +---------+--------------------+-----------+

# %%
spark.sql("""
CREATE TABLE IF NOT EXISTS demo.quality.bronze_quarantine (
    quarantine_id STRING,
    detected_at TIMESTAMP,
    source_table STRING,
    record_id STRING,
    failed_rule STRING,
    severity STRING,
    failure_reason STRING,
    raw_record STRING,
    raw_payload STRING,
    quarantine_status STRING
)
USING iceberg
""")
# Out:
# DataFrame[]

# %%
spark.sql("""
SHOW TABLES IN demo.quality
""").show(truncate=False)
# Out:
# +---------+----------------------+-----------+
# |namespace|tableName             |isTemporary|
# +---------+----------------------+-----------+
# |quality  |bronze_quality_results|false      |
# |quality  |bronze_quarantine     |false      |
# +---------+----------------------+-----------+
