# %%
spark.sql("""
SHOW NAMESPACES IN demo
""").show()
# Out:
# +---------+
# |namespace|
# +---------+
# |   bronze|
# |  quality|
# |     gold|
# |   silver|
# +---------+

# %%
spark.sql("""
CREATE TABLE IF NOT EXISTS demo.silver.learner_profiles (
    user_id STRING,
    registration_date DATE,
    preferred_language STRING,
    background_level STRING,
    learning_goal STRING,
    main_domain STRING,
    profile_updated_at TIMESTAMP,
    ingestion_time TIMESTAMP,
    is_current BOOLEAN
)
USING iceberg
""")
# Out:
# DataFrame[]

# %%
spark.sql("""
DESCRIBE TABLE demo.silver.learner_profiles
""").show(truncate=False)
# Out:
# +------------------+---------+-------+
# |col_name          |data_type|comment|
# +------------------+---------+-------+
# |user_id           |string   |NULL   |
# |registration_date |date     |NULL   |
# |preferred_language|string   |NULL   |
# |background_level  |string   |NULL   |
# |learning_goal     |string   |NULL   |
# |main_domain       |string   |NULL   |
# |profile_updated_at|timestamp|NULL   |
# |ingestion_time    |timestamp|NULL   |
# |is_current        |boolean  |NULL   |
# +------------------+---------+-------+

# %%
spark.sql("""
CREATE TABLE IF NOT EXISTS demo.silver.question_bank (
    question_id STRING,
    question_version INT,
    question_text STRING,
    question_type STRING,
    domain STRING,
    topic STRING,
    subtopic STRING,
    difficulty_level INT,
    option_a_text STRING,
    option_b_text STRING,
    option_c_text STRING,
    option_d_text STRING,
    correct_option_letter STRING,
    created_by STRING,
    generation_model STRING,
    created_at TIMESTAMP,
    is_active BOOLEAN,
    validation_status STRING,
    content_hash STRING
)
USING iceberg
""")
# Out:
# DataFrame[]

# %%
spark.sql("""
DESCRIBE TABLE demo.silver.question_bank
""").show(truncate=False)
# Out:
# +---------------------+---------+-------+
# |col_name             |data_type|comment|
# +---------------------+---------+-------+
# |question_id          |string   |NULL   |
# |question_version     |int      |NULL   |
# |question_text        |string   |NULL   |
# |question_type        |string   |NULL   |
# |domain               |string   |NULL   |
# |topic                |string   |NULL   |
# |subtopic             |string   |NULL   |
# |difficulty_level     |int      |NULL   |
# |option_a_text        |string   |NULL   |
# |option_b_text        |string   |NULL   |
# |option_c_text        |string   |NULL   |
# |option_d_text        |string   |NULL   |
# |correct_option_letter|string   |NULL   |
# |created_by           |string   |NULL   |
# |generation_model     |string   |NULL   |
# |created_at           |timestamp|NULL   |
# |is_active            |boolean  |NULL   |
# |validation_status    |string   |NULL   |
# |content_hash         |string   |NULL   |
# +---------------------+---------+-------+

# %%
spark.sql("""
CREATE TABLE IF NOT EXISTS demo.silver.reference_materials (
    reference_id STRING,
    batch_id STRING,
    source_type STRING,
    source_name STRING,
    file_name STRING,
    import_time TIMESTAMP,
    ingestion_time TIMESTAMP,
    domain STRING,
    title STRING,
    topic STRING,
    content_text STRING,
    reliability_level STRING,
    author_or_owner STRING,
    content_hash STRING,
    is_active BOOLEAN
)
USING iceberg
""")
# Out:
# DataFrame[]

# %%
spark.sql("""
DESCRIBE TABLE demo.silver.reference_materials
""").show(truncate=False)
# Out:
# +-----------------+---------+-------+
# |col_name         |data_type|comment|
# +-----------------+---------+-------+
# |reference_id     |string   |NULL   |
# |batch_id         |string   |NULL   |
# |source_type      |string   |NULL   |
# |source_name      |string   |NULL   |
# |file_name        |string   |NULL   |
# |import_time      |timestamp|NULL   |
# |ingestion_time   |timestamp|NULL   |
# |domain           |string   |NULL   |
# |title            |string   |NULL   |
# |topic            |string   |NULL   |
# |content_text     |string   |NULL   |
# |reliability_level|string   |NULL   |
# |author_or_owner  |string   |NULL   |
# |content_hash     |string   |NULL   |
# |is_active        |boolean  |NULL   |
# +-----------------+---------+-------+

# %%
spark.sql("""
CREATE TABLE IF NOT EXISTS demo.silver.learning_events (
    event_id STRING,
    user_id STRING,
    session_id STRING,
    event_type STRING,
    event_time TIMESTAMP,
    ingestion_time TIMESTAMP,
    source_system STRING,
    event_date DATE,
    event_hour INT,
    payload_valid BOOLEAN,
    processing_status STRING
)
USING iceberg
""")
# Out:
# DataFrame[]

# %%
spark.sql("""
DESCRIBE TABLE demo.silver.learning_events
""").show(truncate=False)
# Out:
# +-----------------+---------+-------+
# |col_name         |data_type|comment|
# +-----------------+---------+-------+
# |event_id         |string   |NULL   |
# |user_id          |string   |NULL   |
# |session_id       |string   |NULL   |
# |event_type       |string   |NULL   |
# |event_time       |timestamp|NULL   |
# |ingestion_time   |timestamp|NULL   |
# |source_system    |string   |NULL   |
# |event_date       |date     |NULL   |
# |event_hour       |int      |NULL   |
# |payload_valid    |boolean  |NULL   |
# |processing_status|string   |NULL   |
# +-----------------+---------+-------+

# %%
spark.sql("""
CREATE TABLE IF NOT EXISTS demo.silver.practice_attempts (
    attempt_id STRING,
    event_id STRING,
    user_id STRING,
    session_id STRING,
    practice_id STRING,
    question_id STRING,
    question_version INT,
    attempt_time TIMESTAMP,
    selected_option_letter STRING,
    is_correct BOOLEAN,
    score FLOAT,
    hints_used INT,
    attempt_duration_seconds INT,
    attempt_number INT
)
USING iceberg
""")
# Out:
# DataFrame[]

# %%
spark.sql("""
DESCRIBE TABLE demo.silver.practice_attempts
""").show(truncate=False)
# Out:
# +------------------------+---------+-------+
# |col_name                |data_type|comment|
# +------------------------+---------+-------+
# |attempt_id              |string   |NULL   |
# |event_id                |string   |NULL   |
# |user_id                 |string   |NULL   |
# |session_id              |string   |NULL   |
# |practice_id             |string   |NULL   |
# |question_id             |string   |NULL   |
# |question_version        |int      |NULL   |
# |attempt_time            |timestamp|NULL   |
# |selected_option_letter  |string   |NULL   |
# |is_correct              |boolean  |NULL   |
# |score                   |float    |NULL   |
# |hints_used              |int      |NULL   |
# |attempt_duration_seconds|int      |NULL   |
# |attempt_number          |int      |NULL   |
# +------------------------+---------+-------+

# %%
spark.sql("""
CREATE TABLE IF NOT EXISTS demo.silver.pre_practice_feedback (
    feedback_id STRING,
    user_id STRING,
    session_id STRING,
    practice_id STRING,
    feedback_time TIMESTAMP,
    ingestion_time TIMESTAMP,
    delay_minutes INT,
    confidence_before_score INT,
    perceived_understanding_before_score INT,
    expected_difficulty_score INT,
    free_text_before STRING
)
USING iceberg
""")
# Out:
# DataFrame[]

# %%
spark.sql("""
DESCRIBE TABLE demo.silver.pre_practice_feedback
""").show(truncate=False)
# Out:
# +------------------------------------+---------+-------+
# |col_name                            |data_type|comment|
# +------------------------------------+---------+-------+
# |feedback_id                         |string   |NULL   |
# |user_id                             |string   |NULL   |
# |session_id                          |string   |NULL   |
# |practice_id                         |string   |NULL   |
# |feedback_time                       |timestamp|NULL   |
# |ingestion_time                      |timestamp|NULL   |
# |delay_minutes                       |int      |NULL   |
# |confidence_before_score             |int      |NULL   |
# |perceived_understanding_before_score|int      |NULL   |
# |expected_difficulty_score           |int      |NULL   |
# |free_text_before                    |string   |NULL   |
# +------------------------------------+---------+-------+

# %%
spark.sql("""
CREATE TABLE IF NOT EXISTS demo.silver.post_practice_feedback (
    feedback_id STRING,
    user_id STRING,
    session_id STRING,
    practice_id STRING,
    feedback_time TIMESTAMP,
    ingestion_time TIMESTAMP,
    delay_minutes INT,
    confidence_after_score INT,
    perceived_understanding_after_score INT,
    perceived_difficulty_score INT,
    still_confused BOOLEAN,
    free_text_after STRING
)
USING iceberg
""")
# Out:
# DataFrame[]

# %%
spark.sql("""
DESCRIBE TABLE demo.silver.post_practice_feedback
""").show(truncate=False)
# Out:
# +-----------------------------------+---------+-------+
# |col_name                           |data_type|comment|
# +-----------------------------------+---------+-------+
# |feedback_id                        |string   |NULL   |
# |user_id                            |string   |NULL   |
# |session_id                         |string   |NULL   |
# |practice_id                        |string   |NULL   |
# |feedback_time                      |timestamp|NULL   |
# |ingestion_time                     |timestamp|NULL   |
# |delay_minutes                      |int      |NULL   |
# |confidence_after_score             |int      |NULL   |
# |perceived_understanding_after_score|int      |NULL   |
# |perceived_difficulty_score         |int      |NULL   |
# |still_confused                     |boolean  |NULL   |
# |free_text_after                    |string   |NULL   |
# +-----------------------------------+---------+-------+

# %%
spark.sql("""
CREATE TABLE IF NOT EXISTS demo.silver.learner_check_in (
    feedback_id STRING,
    user_id STRING,
    session_id STRING,
    topic_id STRING,
    feedback_time TIMESTAMP,
    ingestion_time TIMESTAMP,
    delay_minutes INT,
    overall_confidence_score INT,
    overall_motivation_score INT,
    overall_stress_score INT,
    perceived_understanding_score INT,
    topic_confidence_score INT,
    still_confused BOOLEAN,
    free_text STRING
)
USING iceberg
""")
# Out:
# DataFrame[]

# %%
spark.sql("""
DESCRIBE TABLE demo.silver.learner_check_in
""").show(truncate=False)
# Out:
# +-----------------------------+---------+-------+
# |col_name                     |data_type|comment|
# +-----------------------------+---------+-------+
# |feedback_id                  |string   |NULL   |
# |user_id                      |string   |NULL   |
# |session_id                   |string   |NULL   |
# |topic_id                     |string   |NULL   |
# |feedback_time                |timestamp|NULL   |
# |ingestion_time               |timestamp|NULL   |
# |delay_minutes                |int      |NULL   |
# |overall_confidence_score     |int      |NULL   |
# |overall_motivation_score     |int      |NULL   |
# |overall_stress_score         |int      |NULL   |
# |perceived_understanding_score|int      |NULL   |
# |topic_confidence_score       |int      |NULL   |
# |still_confused               |boolean  |NULL   |
# |free_text                    |string   |NULL   |
# +-----------------------------+---------+-------+

# %%
spark.sql("""
CREATE TABLE IF NOT EXISTS demo.silver.ai_extracted_insights (
    insight_id STRING,
    event_id STRING,
    user_id STRING,
    session_id STRING,
    extracted_at TIMESTAMP,
    dynamic_concept_name STRING,
    extraction_confidence FLOAT,
    processing_model STRING,
    validation_status STRING,
    ai_attributes STRING
)
USING iceberg
""")
# Out:
# DataFrame[]

# %%
spark.sql("""
DESCRIBE TABLE demo.silver.ai_extracted_insights
""").show(truncate=False)
# Out:
# +---------------------+---------+-------+
# |col_name             |data_type|comment|
# +---------------------+---------+-------+
# |insight_id           |string   |NULL   |
# |event_id             |string   |NULL   |
# |user_id              |string   |NULL   |
# |session_id           |string   |NULL   |
# |extracted_at         |timestamp|NULL   |
# |dynamic_concept_name |string   |NULL   |
# |extraction_confidence|float    |NULL   |
# |processing_model     |string   |NULL   |
# |validation_status    |string   |NULL   |
# |ai_attributes        |string   |NULL   |
# +---------------------+---------+-------+

# %%
spark.sql("""
CREATE TABLE IF NOT EXISTS demo.silver.validated_learning_insights (
    validation_id STRING,
    insight_id STRING,
    reference_id STRING,
    user_id STRING,
    session_id STRING,
    dynamic_concept_name STRING,
    validation_time TIMESTAMP,
    semantic_match_score FLOAT,
    reliability_score FLOAT,
    contradiction_flag BOOLEAN,
    validation_notes STRING,
    validation_status STRING
)
USING iceberg
""")
# Out:
# DataFrame[]

# %%
spark.sql("""
DESCRIBE TABLE demo.silver.validated_learning_insights
""").show(truncate=False)
# Out:
# +--------------------+---------+-------+
# |col_name            |data_type|comment|
# +--------------------+---------+-------+
# |validation_id       |string   |NULL   |
# |insight_id          |string   |NULL   |
# |reference_id        |string   |NULL   |
# |user_id             |string   |NULL   |
# |session_id          |string   |NULL   |
# |dynamic_concept_name|string   |NULL   |
# |validation_time     |timestamp|NULL   |
# |semantic_match_score|float    |NULL   |
# |reliability_score   |float    |NULL   |
# |contradiction_flag  |boolean  |NULL   |
# |validation_notes    |string   |NULL   |
# |validation_status   |string   |NULL   |
# +--------------------+---------+-------+

# %%
spark.sql("""
SHOW TABLES IN demo.silver
""").show(truncate=False)
# Out:
# +---------+---------------------------+-----------+
# |namespace|tableName                  |isTemporary|
# +---------+---------------------------+-----------+
# |silver   |ai_extracted_insights      |false      |
# |silver   |learner_check_in           |false      |
# |silver   |learner_profiles           |false      |
# |silver   |learning_events            |false      |
# |silver   |post_practice_feedback     |false      |
# |silver   |practice_attempts          |false      |
# |silver   |pre_practice_feedback      |false      |
# |silver   |question_bank              |false      |
# |silver   |reference_materials        |false      |
# |silver   |validated_learning_insights|false      |
# +---------+---------------------------+-----------+

# %%
spark.sql("""
DROP TABLE IF EXISTS demo.silver.learner_check_in
""")
# Out:
# DataFrame[]

# %%
spark.sql("""
CREATE TABLE IF NOT EXISTS demo.silver.learner_check_in (
    feedback_id STRING,
    user_id STRING,
    session_id STRING,
    feedback_time TIMESTAMP,
    ingestion_time TIMESTAMP,
    delay_minutes INT,
    overall_confidence_score INT,
    overall_motivation_score INT,
    overall_stress_score INT,
    free_text STRING
)
USING iceberg
""")
# Out:
# DataFrame[]

# %%
spark.sql("""
CREATE TABLE IF NOT EXISTS demo.silver.learner_check_in_topics (
    feedback_id STRING,
    user_id STRING,
    session_id STRING,
    topic_id STRING,
    feedback_time TIMESTAMP,
    perceived_understanding_score INT,
    topic_confidence_score INT,
    still_confused BOOLEAN
)
USING iceberg
""")
# Out:
# DataFrame[]

# %%
spark.sql("""
SHOW TABLES IN demo.silver
""").show(truncate=False)
# Out:
# +---------+---------------------------+-----------+
# |namespace|tableName                  |isTemporary|
# +---------+---------------------------+-----------+
# |silver   |ai_extracted_insights      |false      |
# |silver   |learner_check_in           |false      |
# |silver   |learner_check_in_topics    |false      |
# |silver   |learner_profiles           |false      |
# |silver   |learning_events            |false      |
# |silver   |post_practice_feedback     |false      |
# |silver   |practice_attempts          |false      |
# |silver   |pre_practice_feedback      |false      |
# |silver   |question_bank              |false      |
# |silver   |reference_materials        |false      |
# |silver   |validated_learning_insights|false      |
# +---------+---------------------------+-----------+
